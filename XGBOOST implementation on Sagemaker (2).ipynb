# %%
# import libraries
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   

# Define IAM role and assign S3 bucket
role = get_execution_role()
prefix = 'sagemaker/wimlds-sagemaker-xgboost-demo'
bucket_name = 'sagemaker-house-prediction-xgbbost' 

containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} 

my_region = boto3.session.Session().region_name 
print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-east-2 region. You will use the 825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %%
data = pd.read_csv('s3://final-assignment/kc_house_data.csv')

# %%
drop_columns = ['id', 'date', 'lat', 'long']

data.drop(drop_columns, 1, inplace = True)
# Out:
# /tmp/ipykernel_3927/3534743728.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data.drop(drop_columns, 1, inplace = True)

# %%
for i in data.columns:

# Remove outliers for each variable
  Q1 = data[i].quantile(0.25)
  Q3 = data[i].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5*IQR
  upper_bound = Q3 + 1.5*IQR

  # Filter the data without outliers
  data = data[(data[i] >= lower_bound) & (data[i] <= upper_bound)]

# %% [markdown]
# ### Prepare the data

# %%
train_data, test_data = np.split(data.sample(frac=1, random_state=1729), [int(0.7 * len(data))])
print(train_data.shape, test_data.shape)
# Out:
# (9898, 17) (4243, 17)

# %%
train_data.head()
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 10503  495000.0         3       2.00         1340      2550     2.0
# 7452   479000.0         3       1.75         1470      6018     1.0
# 8000   355200.0         3       1.00         1120      7320     1.0
# 11621  565000.0         4       1.00         1540      2452     1.5
# 191    166950.0         3       1.00         1190      8820     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 10503           0     0          3      7        1340              0
# 7452            0     0          3      8        1470              0
# 8000            0     0          4      7        1120              0
# 11621           0     0          4      7        1540              0
# 191             0     0          3      6        1190              0
#
#        yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15
# 10503      1984             0    98117           1370        5100
# 7452       1987             0    98074           1720        6584
# 8000       1954             0    98146           1410        6328
# 11621      1906             0    98103           1290        3360
# 191        1959             0    98058           1230        7980

# %%
len(train_data.columns)
# Out:
# 17

# %% [markdown]
# Amazon SageMaker's XGBoost container expects data in the libSVM or CSV data format. For this example, we'll stick to CSV. Note that the first column must be the target variable and the CSV should not include headers. Also, notice that although repetitive it's easiest to do this after the train|validation|test split rather than before. This avoids any misalignment issues due to random reordering.

# %%
attributes = ['price','bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_living15', 'sqft_lot15']
len(attributes)
# Out:
# 16

# %%
train_data = train_data[attributes]

# %%
# Experiment scaling and not scaling it
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# train_data = scaler.fit_transform(train_data)
# train_data = pd.DataFrame(train_data)

# %%
train_data.to_csv('train.csv', index=False, header=False)

# %% [markdown]
# ### Upload training data to S3 Bucket

# %%
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')

s3_input_train = sagemaker.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %%
bucket_name
# Out:
# 'sagemaker-house-prediction-xgbbost'

# %% [markdown]
# ### Training
#
# First we'll need to specify training parameters to the estimator. This includes:
#
# - The xgboost algorithm container
# - The IAM role to use
# - Training instance type and count
# - S3 location for output data
# - Algorithm hyperparameters
#
# And then a .fit() function which specifies:
#
# S3 location for output data. In this case we have both a training and validation set which are passed in.

# %%
sess = sagemaker.Session()

# %% [markdown]
# ### XG Boost Hyperparamaters
#
#
# There are lot of hyperparameters, few of them are :
#
# 1. Subsample
#     - Subsample ratio of the training instance.
#     - Setting it to 0.5 means that XGBoost randomly collects half of the data instances to grow trees.
#     - This prevents overfitting.
#
#         Optional
#
#         Valid values: Float. Range: [0,1].
#
#         Default value: 1
# 2. Eta
#     - Step size shrinkage, prevents overfitting.
# 3. Gamma
#     - Minimum loss reduction to create a partition, larger = more conservative
# 4. Alpha
#     - L1 regularization term; larger = more conservative
# 5. Lambda
#     - L2 regularization term; larger = more conservative

# %%
xgb = sagemaker.estimator.Estimator(containers[my_region],
                                    role, 
                                    train_instance_count=1, 
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket_name, prefix),
                                    sagemaker_session=sess)
xgb.set_hyperparameters(eta=0.06,
                        alpha=0.8,
                        lambda_bias=0.8,
                        gamma=50,
                        min_child_weight=6,
                        subsample=0.5,
                        silent=0,
                        early_stopping_rounds=5,
                        objective='reg:linear',
                        num_round=1000)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
xgb.fit({'train': s3_input_train})
# Out:
# INFO:sagemaker:Creating training-job with name: xgboost-2023-03-14-12-13-25-561
# 2023-03-14 12:13:25 Starting - Starting the training job...
# 2023-03-14 12:13:49 Starting - Preparing the instances for training......
# 2023-03-14 12:14:50 Downloading - Downloading input data...
# 2023-03-14 12:15:15 Training - Downloading the training image...
# 2023-03-14 12:15:51 Training - Training image download completed. Training in progress...Arguments: train
# [2023-03-14:12:16:05:INFO] Running standalone xgboost training.
# [2023-03-14:12:16:05:INFO] Path /opt/ml/input/data/validation does not exist!
# [2023-03-14:12:16:05:INFO] File size need to be processed in the node: 0.6mb. Available memory size in the node: 8599.93mb
# [2023-03-14:12:16:05:INFO] Determined delimiter of CSV input is ','
# [12:16:05] S3DistributionType set as FullyReplicated
# [12:16:05] 9898x15 matrix with 148470 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [12:16:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-rmse:434645
# Will train until train-rmse hasn't improved in 5 rounds.
# [12:16:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-rmse:410760
# [12:16:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-rmse:388373
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-rmse:367573
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-rmse:348048
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-rmse:329724
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-rmse:312382
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-rmse:296326
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-rmse:281291
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-rmse:267088
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-rmse:253974
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-rmse:241852
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-rmse:230511
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-rmse:219933
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-rmse:210000
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-rmse:200734
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-rmse:192172
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-rmse:184227
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-rmse:176890
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-rmse:170139
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-rmse:163783
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-rmse:157726
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-rmse:152266
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-rmse:147202
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-rmse:142433
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [25]#011train-rmse:138161
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-rmse:133887
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [27]#011train-rmse:129914
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [28]#011train-rmse:126189
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [29]#011train-rmse:122757
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=6
# [30]#011train-rmse:119628
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [31]#011train-rmse:117024
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [32]#011train-rmse:114492
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [33]#011train-rmse:112200
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [34]#011train-rmse:110085
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-rmse:108240
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [36]#011train-rmse:106239
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-rmse:104390
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [38]#011train-rmse:102655
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [39]#011train-rmse:101388
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [40]#011train-rmse:99935.7
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [41]#011train-rmse:98555
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [42]#011train-rmse:97461.5
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [43]#011train-rmse:96102.4
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [44]#011train-rmse:94656.1
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [45]#011train-rmse:93731
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [46]#011train-rmse:92644.8
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [47]#011train-rmse:91834.3
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [48]#011train-rmse:90797.3
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [49]#011train-rmse:89920.1
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [50]#011train-rmse:89167.3
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [51]#011train-rmse:88475.1
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [52]#011train-rmse:87875.1
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [53]#011train-rmse:87136.5
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [54]#011train-rmse:86623.4
# [55]#011train-rmse:86194.9
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [56]#011train-rmse:85661.5
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [57]#011train-rmse:84797.4
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [58]#011train-rmse:84179.9
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [59]#011train-rmse:83868.9
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [60]#011train-rmse:83484.1
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [61]#011train-rmse:82783.6
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [62]#011train-rmse:81731.8
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [63]#011train-rmse:80946.6
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [64]#011train-rmse:80700.9
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [65]#011train-rmse:80264.7
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [66]#011train-rmse:79911.2
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [67]#011train-rmse:79455.7
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [68]#011train-rmse:78619.4
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [69]#011train-rmse:78224.6
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [70]#011train-rmse:77802.9
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [71]#011train-rmse:77558.1
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [72]#011train-rmse:77230.8
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [73]#011train-rmse:77039.3
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [74]#011train-rmse:76846.9
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [75]#011train-rmse:76277.8
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [76]#011train-rmse:75895.9
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [77]#011train-rmse:75721.2
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [78]#011train-rmse:75429.4
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [79]#011train-rmse:75067.7
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [80]#011train-rmse:74630.3
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [81]#011train-rmse:73974.3
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-rmse:73818.7
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [83]#011train-rmse:73447.1
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [84]#011train-rmse:73154
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [85]#011train-rmse:72817.3
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [86]#011train-rmse:72566.5
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [87]#011train-rmse:72302.9
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [88]#011train-rmse:72055
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [89]#011train-rmse:71893.4
# [12:16:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
#
# [12:16:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [941]#011train-rmse:33103
# [12:16:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [942]#011train-rmse:33082.3
# [12:16:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [943]#011train-rmse:33060.7
# [12:16:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [944]#011train-rmse:33037.6
# [12:16:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [945]#011train-rmse:33028.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [946]#011train-rmse:33014.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [947]#011train-rmse:32988.6
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [948]#011train-rmse:32970.9
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [949]#011train-rmse:32951.5
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [950]#011train-rmse:32927.1
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [951]#011train-rmse:32902.1
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [952]#011train-rmse:32885.8
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [953]#011train-rmse:32865
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [954]#011train-rmse:32850
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [955]#011train-rmse:32834.1
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [956]#011train-rmse:32811.1
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [957]#011train-rmse:32788.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [958]#011train-rmse:32773.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [959]#011train-rmse:32755.1
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [960]#011train-rmse:32734.4
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [961]#011train-rmse:32719.8
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [962]#011train-rmse:32695.1
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [963]#011train-rmse:32663.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [964]#011train-rmse:32654.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [965]#011train-rmse:32624.4
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [966]#011train-rmse:32598.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [967]#011train-rmse:32578.7
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [968]#011train-rmse:32555.6
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [969]#011train-rmse:32521.5
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [970]#011train-rmse:32509.9
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [971]#011train-rmse:32497.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [972]#011train-rmse:32480.6
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [973]#011train-rmse:32462.7
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [974]#011train-rmse:32444.1
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [975]#011train-rmse:32430.9
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [976]#011train-rmse:32398.9
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [977]#011train-rmse:32375.3
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [978]#011train-rmse:32352.3
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [979]#011train-rmse:32325.6
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [980]#011train-rmse:32304.5
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [981]#011train-rmse:32279.8
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [982]#011train-rmse:32252.5
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [983]#011train-rmse:32243.4
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [984]#011train-rmse:32232.3
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [985]#011train-rmse:32203.4
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [986]#011train-rmse:32184.8
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [987]#011train-rmse:32164.7
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [988]#011train-rmse:32135.5
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [989]#011train-rmse:32104
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [990]#011train-rmse:32095.9
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [991]#011train-rmse:32064
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [992]#011train-rmse:32041.7
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [993]#011train-rmse:32017.6
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [994]#011train-rmse:31998.9
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [995]#011train-rmse:31979.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [996]#011train-rmse:31964.6
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [997]#011train-rmse:31948.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [998]#011train-rmse:31918.2
# [12:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [999]#011train-rmse:31895.4
#
# 2023-03-14 12:16:32 Completed - Training job completed
# Training seconds: 102
# Billable seconds: 102

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: xgboost-2023-03-14-12-17-14-846
# INFO:sagemaker:Creating endpoint-config with name xgboost-2023-03-14-12-17-14-846
# INFO:sagemaker:Creating endpoint with name xgboost-2023-03-14-12-17-14-846
# ------!

# %% [markdown]
# ### Evaluation
#
# There are many ways to compare the performance of a machine learning model, but let's start by simply comparing actual to predicted values.
#
# First we'll need to determine how we pass data into and receive data from our endpoint. Our data is currently stored as NumPy arrays in memory of our notebook instance. To send it in an HTTP POST request, we'll serialize it as a CSV string and then decode the resulting CSV.
#
# Note: For inference with CSV format, SageMaker XGBoost requires that the data does NOT include the target variable.

# %%
test_data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')

# %%
train_data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_basement', 'yr_built',
#        'yr_renovated', 'zipcode', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
test_data_array = test_data.drop([ 'price','sqft_above'], axis=1).values

# %%
xgb_predictor.__setattr__(xgb_predictor.content_type, "text/csv")
xgb_predictor.serializer = csv_serializer # set the serializer type

# %%
predictions = xgb_predictor.predict(test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# WARNING:sagemaker.deprecations:The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# (4243,)

# %%
from sklearn.metrics import r2_score
print("R2 score : %.2f" % r2_score(test_data['price'],predictions_array))
# Out:
# R2 score : 0.83
